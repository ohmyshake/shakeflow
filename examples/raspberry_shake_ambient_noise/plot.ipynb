# %%
import sys
import itables
sys.path.append('/Users/yinfu/ohmyshake/noisecc')
sys.path.append('/Users/yinfu/ohmyshake/shakecore')

import numpy as np
import noisecc as nc
import shakecore as sc

# %%
pool = sc.read('./database/*.h5', format='sc', backend='shakecore')

pool[0].data[np.isnan(pool[0].data)] = 0
pool[0].viz.plot(amp_scale=10)

pool[0]
# Out:
# * ID:
#       d3cb777f4ef2c82918e6c90ebe37fab99238236d990e7e0c58e27676129b6ab7
# * STATS:
#          starttime: 2023-11-30T08:50:31.062941Z
#            endtime: 2023-11-30T09:20:31.052941Z
#      sampling_rate: 100.0
#              delta: 0.01
#           interval: 0.0
#               npts: 180000
#          trace_num: 19
#               type: velocity
#            network: ['AM', 'AM', 'AM', ..., 'AM', 'AM', 'AM']
#            station: ['RF926', 'R3CDE', 'R27ED', ..., 'RF5C1', 'R37A5', 'R0EBF']
#            channel: ['EHZ', 'EHZ', 'EHZ', ..., 'EHZ', 'EHZ', 'EHZ']
#           latitude: [48.51351351,         nan, 48.48648649, ..., 48.42342342, 48.42342342,
#    48.41441441]
#          longitude: [-123.3683844,          nan, -123.3966204, ..., -123.314634 , -123.3092842,
#    -123.3255172]
#          elevation: [85., nan, 40., ..., 18., 29., 23.]
#         processing: []
#              notes: {}
#            _format: sc
#                 sc: {}
# * DATA:
#        shape: (19, 180000)
# ...

# %%
# Out:
# * ID:
#       7d9caec580cc1da320fc53384d4bca609c4e38db71c3675a620aa282418fa29e
# * STATS:
#          starttime: 2023-11-30T02:56:16.176957Z
#            endtime: 2023-11-30T03:06:16.176957Z
#      sampling_rate: 100.0
#              delta: 0.01
#           interval: 0.0
#               npts: 60001
#          trace_num: 2
#               type: velocity
#            network: ['AM', 'AM']
#            station: ['RF926', 'R3CDE']
#            channel: ['EHZ', 'EHZ']
#           latitude: [48.51351351,         nan]
#          longitude: [-123.3683844,          nan]
#          elevation: [85., nan]
#         processing: []
#              notes: {}
#            _format: sc
#                 sc: {}
# * DATA:
#        shape: (2, 60001)
#        dtype: float64
#       masked: False
#       [[ 1.13543836e-06  1.14368633e-06  1.13726150e-06 ... -7.08585365e-07
#         -7.07696240e-07 -7.07210012e-07]
#        [            nan             nan             nan ...             nan
# ...

# %%
files=['/Users/yinfu/ohmyshake/shakeflow/examples/raspberry_shake_ambient_noise/download/2023_11_30_09_33_38_998562_EHZ.h5', '/Users/yinfu/ohmyshake/shakeflow/examples/raspberry_shake_ambient_noise/download/2023_11_30_09_43_38_998562_EHZ.h5', '/Users/yinfu/ohmyshake/shakeflow/examples/raspberry_shake_ambient_noise/download/2023_11_30_09_53_38_998562_EHZ.h5']
pool = sc.read(files, format='sc', backend='shakecore')

# %%
pool.show()
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="ef42bf88-fd7d-4f2c-8fe9-6550d54f60fc" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#
#       <th>index</th>
#       <th>starttime</th>
#       <th>endtime</th>
#       <th>duration</th>
#       <th>sampling_rate</th>
#       <th>delta</th>
#       <th>interval</th>
#       <th>npts</th>
#       <th>trace_num</th>
#       <th>type</th>
#       <th>data_masked</th>
#       <th>id</th>
#       <th>notes</th>
#       <th>processing</th>
#     </tr>
# ...

# %%
pool[1]
# Out:
# * ID:
#       ecc788a3d8744024fafb367e2f99e523ee379d8900c157a8cd73e1ef5d6a70cb
# * STATS:
#          starttime: 2023-11-30T09:43:38.998562Z
#            endtime: 2023-11-30T09:53:38.988562Z
#      sampling_rate: 100.0
#              delta: 0.01
#           interval: 0.0
#               npts: 60000
#          trace_num: 4
#               type: velocity
#            network: ['AM', 'AM', 'AM', 'AM']
#            station: ['RF926', 'R3CDE', 'R27ED', 'RC2BF']
#            channel: ['EHZ', 'EHZ', 'EHZ', 'EHZ']
#           latitude: [48.51351351,         nan, 48.48648649, 48.47747748]
#          longitude: [-123.3683844,          nan, -123.3966204, -123.3723234]
#          elevation: [85., nan, 40., 60.]
#         processing: []
#              notes: {}
#            _format: sc
#                 sc: {}
# * DATA:
#        shape: (4, 60000)
#        dtype: float64
#       masked: False
#       [[ 8.77360520e-07  1.14696327e-06  1.12750030e-06 ...  3.07481891e-08
# ...

# %%
pool[2]
# Out:
# * ID:
#       0bc1d410c9481a338185ee55deaf2c0e71731e13a19425229d30117b05999ffd
# * STATS:
#          starttime: 2023-11-30T09:53:38.998562Z
#            endtime: 2023-11-30T10:03:38.988562Z
#      sampling_rate: 100.0
#              delta: 0.01
#           interval: 0.0
#               npts: 60000
#          trace_num: 4
#               type: velocity
#            network: ['AM', 'AM', 'AM', 'AM']
#            station: ['RF926', 'R3CDE', 'R27ED', 'RC2BF']
#            channel: ['EHZ', 'EHZ', 'EHZ', 'EHZ']
#           latitude: [48.51351351,         nan,         nan, 48.47747748]
#          longitude: [-123.3683844,          nan,          nan, -123.3723234]
#          elevation: [85., nan, nan, 60.]
#         processing: []
#              notes: {}
#            _format: sc
#                 sc: {}
# * DATA:
#        shape: (4, 60000)
#        dtype: float64
#       masked: False
#       [[-8.42518267e-07 -1.12276582e-06 -1.10245351e-06 ...  2.76810064e-08
# ...
